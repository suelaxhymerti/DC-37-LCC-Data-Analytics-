# %% [markdown]
# ---

# %% [markdown]
# Research Question: How does School 01M140 percent of students scoring 65 or above compare to the average across all schools in the dataset?

# %%
import pandas as pd
import seaborn as sns
url = "https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
school_id="01M140"
school_df=df[df["School DBN"]==school_id]
school_df
# Out:
#        School DBN             School Name School Level         Regents Exam  \
# 3          01M140  P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 4          01M140  P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 5          01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 6          01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 7          01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 19482      01M140  P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 19483      01M140  P.S. 140 Nathan Straus          K-8  Common Core Algebra
# 19484      01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 19485      01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 19486      01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# 19487      01M140  P.S. 140 Nathan Straus          K-8   Living Environment
# ...

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
school_id="01M140"
feature="Percent Scoring 65 or Above"
school_df[["School DBN", "School Name", feature]]
# Out:
#        School DBN             School Name Percent Scoring 65 or Above
# 3          01M140  P.S. 140 Nathan Straus                           s
# 4          01M140  P.S. 140 Nathan Straus                           s
# 5          01M140  P.S. 140 Nathan Straus                        66.7
# 6          01M140  P.S. 140 Nathan Straus                        86.7
# 7          01M140  P.S. 140 Nathan Straus                        44.4
# 19482      01M140  P.S. 140 Nathan Straus                           s
# 19483      01M140  P.S. 140 Nathan Straus                           s
# 19484      01M140  P.S. 140 Nathan Straus                           s
# 19485      01M140  P.S. 140 Nathan Straus                           s
# 19486      01M140  P.S. 140 Nathan Straus                           s
# 19487      01M140  P.S. 140 Nathan Straus                           s
# 19488      01M140  P.S. 140 Nathan Straus                        44.4
# ...

# %%
my_school_value = school_df[feature].mean()
all_schools_mean = df[feature].mean()
my_school_value, all_schools_mean
# Out:
# (np.float64(64.75714285714285), np.float64(58.06785477248029))

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df[feature].describe()
# Out:
# count    137109.000000
# mean         58.067855
# std          28.405517
# min           0.000000
# 25%          36.000000
# 50%          59.800000
# 75%          82.500000
# max         100.000000
# Name: Percent Scoring 65 or Above, dtype: float64

# %%
df_clean=df.dropna(subset=[feature])
df_clean.shape
# Out:
# (137109, 15)

# %%
all_mean=df_clean[feature].mean()
df_clean[feature].hist()
# Out:
# <Axes: >

# %% [markdown]
# Conclusion: The histogram shows that most values for my chosen feature are concentrated near the high end of the range. This reports that in general the observations in this dataset perform well on this measure.
